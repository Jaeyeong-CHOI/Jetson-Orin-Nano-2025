# %% [markdown]
# # Thumbs Up/Down 분류 파이프라인 (캡처 ↔ 학습 ↔ 실시간 분류)
# 요구 반영:
# - **카메라 창 크게** 띄우기 (`cv2.WINDOW_NORMAL + resizeWindow(1280x720)`)
# - **데이터 촬영**과 **모델 분류(실시간)** **완전히 분리**
# - PyTorch `resnet18` 전이학습 기반 (원본 코드 구조/하이퍼파라미터 최대한 유지)

# %% [markdown]
# ## 0) 설정
# - 데이터는 `data_dir/라벨/파일.jpg` 형태로 저장 (`THUMBS_UP`, `THUMBS_DOWN`)
# - 모델 가중치는 `./models/` 아래에 저장
# - Jetson Orin Nano에서도 동작하도록 카메라 초기화 루틴(재시도) 포함

# %%
import os, time, cv2, torch, numpy as np
from pathlib import Path
from datetime import datetime

# 경로/클래스
data_dir = Path("./thumbs_data")
model_dir = Path("./models")
model_dir.mkdir(parents=True, exist_ok=True)

CLASS_NAMES = {0:"THUMBS_UP", 1:"THUMBS_DOWN"}
CLASS_DIRS = [CLASS_NAMES[i] for i in sorted(CLASS_NAMES.keys())]  # ["THUMBS_UP", "THUMBS_DOWN"]
for c in CLASS_DIRS:
    (data_dir / c).mkdir(parents=True, exist_ok=True)

# 창/카메라 설정
WINDOW_NAME = "Camera"
REQ_W, REQ_H, REQ_FPS = 1280, 720, 30

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## 1) 카메라 초기화 (재시도 포함)
# 여러 백엔드/포맷 조합으로 시도 → 안정적으로 프레임이 읽히는 설정을 자동 선택합니다.

# %%
def setup_camera_with_retry():
    methods = [
        {
            'name': 'V4L2_YUYV',
            'backend': cv2.CAP_V4L2,
            'settings': {
                'fourcc': cv2.VideoWriter_fourcc('Y', 'U', 'Y', 'V'),
                'width': REQ_W,
                'height': REQ_H,
                'fps': REQ_FPS,
                'buffersize': 1,
            }
        },
        {
            'name': 'V4L2_MJPEG',
            'backend': cv2.CAP_V4L2,
            'settings': {
                'fourcc': cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'),
                'width': REQ_W,
                'height': REQ_H,
                'fps': REQ_FPS,
                'buffersize': 1,
            }
        },
        {
            'name': 'DEFAULT',
            'backend': None,
            'settings': {
                'width': REQ_W,
                'height': REQ_H,
                'fps': REQ_FPS,
                'buffersize': 1,
            }
        },
    ]
    for method in methods:
        print(f"Attempting {method['name']}...")
        try:
            cap = cv2.VideoCapture(0) if method['backend'] is None else cv2.VideoCapture(0, method['backend'])
            if not cap.isOpened():
                print(f"Failed to open camera with {method['name']}")
                continue
            st = method['settings']
            if 'fourcc' in st: cap.set(cv2.CAP_PROP_FOURCC, st['fourcc'])
            cap.set(cv2.CAP_PROP_FRAME_WIDTH, st['width'])
            cap.set(cv2.CAP_PROP_FRAME_HEIGHT, st['height'])
            cap.set(cv2.CAP_PROP_FPS, st['fps'])
            cap.set(cv2.CAP_PROP_BUFFERSIZE, st['buffersize'])
            time.sleep(1.0)
            ok_count = 0
            for _ in range(5):
                ret, frm = cap.read()
                if ret and frm is not None: ok_count += 1
                time.sleep(0.05)
            if ok_count >= 3:
                print(f"Camera initialized successfully with {method['name']}")
                return cap, method['name']
            print(f"Frame unstable with {method['name']}")
            cap.release()
        except Exception as e:
            print(f"Error with {method['name']}: {e}")
    return None, None

# %% [markdown]
# ## 2) 데이터 촬영 전용 셀
# - 창을 **크게** 띄우고, 라벨은 키보드로 선택 후 `s`를 눌러 저장
# - `0`: THUMBS_UP, `1`: THUMBS_DOWN, `q`: 종료

# %%
import cv2
from collections import deque

label_idx = 0  # 0:UP, 1:DOWN

cap, method = setup_camera_with_retry()
if cap is None:
    raise RuntimeError("Camera initialization failed. Try reloading kernel or checking permissions.")

cv2.namedWindow(WINDOW_NAME, cv2.WINDOW_NORMAL)
cv2.resizeWindow(WINDOW_NAME, REQ_W, REQ_H)

print("데이터 촬영 시작: 0/1 라벨 선택, s=저장, q=종료")
saved = 0
try:
    while True:
        ret, frame = cap.read()
        if not ret or frame is None:
            print("Frame read failed."); time.sleep(0.1); continue
        frame = cv2.flip(frame, 1)
        msg = f"Label[{label_idx}] {CLASS_NAMES[label_idx]} | s=save | q=quit | method={method}"
        cv2.putText(frame, msg, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,255,0), 2, cv2.LINE_AA)
        cv2.imshow(WINDOW_NAME, frame)
        k = cv2.waitKey(1) & 0xFF
        if k == ord('q') or k == 27: break
        if k == ord('0'): label_idx = 0
        if k == ord('1'): label_idx = 1
        if k == ord('s'):
            ts = datetime.now().strftime("%Y%m%d_%H%M%S_%f")[:-3]
            out_path = data_dir / CLASS_NAMES[label_idx] / f"{ts}.jpg"
            cv2.imwrite(str(out_path), frame)
            saved += 1
            print(f"Saved: {out_path} (total {saved})")
finally:
    cap.release()
    cv2.destroyAllWindows()
    print("촬영 종료")
# Out:
# Attempting V4L2_YUYV...
# Failed to open camera with V4L2_YUYV
# Attempting V4L2_MJPEG...
# Failed to open camera with V4L2_MJPEG
# Attempting DEFAULT...
# Camera initialized successfully with DEFAULT
# 데이터 촬영 시작: 0/1 라벨 선택, s=저장, q=종료
# Saved: thumbs_data\THUMBS_UP\20250816_195324_346.jpg (total 1)
# Saved: thumbs_data\THUMBS_UP\20250816_195324_922.jpg (total 2)
# Saved: thumbs_data\THUMBS_UP\20250816_195325_291.jpg (total 3)
# Saved: thumbs_data\THUMBS_UP\20250816_195325_515.jpg (total 4)
# Saved: thumbs_data\THUMBS_UP\20250816_195325_722.jpg (total 5)
# Saved: thumbs_data\THUMBS_UP\20250816_195325_962.jpg (total 6)
# Saved: thumbs_data\THUMBS_UP\20250816_195326_155.jpg (total 7)
# Saved: thumbs_data\THUMBS_UP\20250816_195326_362.jpg (total 8)
# Saved: thumbs_data\THUMBS_UP\20250816_195326_555.jpg (total 9)
# Saved: thumbs_data\THUMBS_UP\20250816_195326_794.jpg (total 10)
# Saved: thumbs_data\THUMBS_UP\20250816_195326_987.jpg (total 11)
# Saved: thumbs_data\THUMBS_UP\20250816_195327_195.jpg (total 12)
# Saved: thumbs_data\THUMBS_UP\20250816_195327_403.jpg (total 13)
# Saved: thumbs_data\THUMBS_UP\20250816_195327_595.jpg (total 14)
# Saved: thumbs_data\THUMBS_UP\20250816_195327_803.jpg (total 15)
# Saved: thumbs_data\THUMBS_UP\20250816_195327_963.jpg (total 16)
# Saved: thumbs_data\THUMBS_UP\20250816_195328_171.jpg (total 17)
# Saved: thumbs_data\THUMBS_UP\20250816_195328_363.jpg (total 18)
# Saved: thumbs_data\THUMBS_UP\20250816_195328_571.jpg (total 19)
# Saved: thumbs_data\THUMBS_UP\20250816_195328_796.jpg (total 20)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_003.jpg (total 21)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_195.jpg (total 22)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_402.jpg (total 23)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_596.jpg (total 24)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_803.jpg (total 25)
# Saved: thumbs_data\THUMBS_UP\20250816_195329_994.jpg (total 26)
# Saved: thumbs_data\THUMBS_UP\20250816_195330_204.jpg (total 27)
# Saved: thumbs_data\THUMBS_UP\20250816_195330_411.jpg (total 28)
# Saved: thumbs_data\THUMBS_UP\20250816_195330_602.jpg (total 29)
# Saved: thumbs_data\THUMBS_UP\20250816_195330_779.jpg (total 30)
# Saved: thumbs_data\THUMBS_UP\20250816_195330_971.jpg (total 31)
# Saved: thumbs_data\THUMBS_UP\20250816_195331_211.jpg (total 32)
# Saved: thumbs_data\THUMBS_UP\20250816_195331_403.jpg (total 33)
# Saved: thumbs_data\THUMBS_UP\20250816_195331_579.jpg (total 34)
# Saved: thumbs_data\THUMBS_UP\20250816_195331_802.jpg (total 35)
# Saved: thumbs_data\THUMBS_UP\20250816_195332_011.jpg (total 36)
# Saved: thumbs_data\THUMBS_UP\20250816_195332_172.jpg (total 37)
# Saved: thumbs_data\THUMBS_UP\20250816_195332_410.jpg (total 38)
# Saved: thumbs_data\THUMBS_UP\20250816_195332_603.jpg (total 39)
# Saved: thumbs_data\THUMBS_UP\20250816_195332_810.jpg (total 40)
# Saved: thumbs_data\THUMBS_UP\20250816_195333_019.jpg (total 41)
# Saved: thumbs_data\THUMBS_UP\20250816_195333_211.jpg (total 42)
# Saved: thumbs_data\THUMBS_UP\20250816_195333_428.jpg (total 43)
# Saved: thumbs_data\THUMBS_UP\20250816_195333_643.jpg (total 44)
# Saved: thumbs_data\THUMBS_UP\20250816_195333_850.jpg (total 45)
# Saved: thumbs_data\THUMBS_UP\20250816_195334_044.jpg (total 46)
# Saved: thumbs_data\THUMBS_UP\20250816_195334_252.jpg (total 47)
# Saved: thumbs_data\THUMBS_UP\20250816_195334_443.jpg (total 48)
# Saved: thumbs_data\THUMBS_UP\20250816_195334_714.jpg (total 49)
# Saved: thumbs_data\THUMBS_UP\20250816_195334_922.jpg (total 50)
# Saved: thumbs_data\THUMBS_UP\20250816_195335_147.jpg (total 51)
# Saved: thumbs_data\THUMBS_UP\20250816_195335_355.jpg (total 52)
# Saved: thumbs_data\THUMBS_UP\20250816_195335_579.jpg (total 53)
# Saved: thumbs_data\THUMBS_UP\20250816_195335_787.jpg (total 54)
# Saved: thumbs_data\THUMBS_UP\20250816_195336_026.jpg (total 55)
# Saved: thumbs_data\THUMBS_UP\20250816_195336_250.jpg (total 56)
# Saved: thumbs_data\THUMBS_UP\20250816_195336_459.jpg (total 57)
# Saved: thumbs_data\THUMBS_UP\20250816_195336_715.jpg (total 58)
# Saved: thumbs_data\THUMBS_UP\20250816_195336_892.jpg (total 59)
# Saved: thumbs_data\THUMBS_UP\20250816_195337_131.jpg (total 60)
# Saved: thumbs_data\THUMBS_UP\20250816_195337_322.jpg (total 61)
# Saved: thumbs_data\THUMBS_UP\20250816_195337_542.jpg (total 62)
# Saved: thumbs_data\THUMBS_UP\20250816_195337_756.jpg (total 63)
# Saved: thumbs_data\THUMBS_UP\20250816_195337_963.jpg (total 64)
# Saved: thumbs_data\THUMBS_UP\20250816_195338_155.jpg (total 65)
# Saved: thumbs_data\THUMBS_UP\20250816_195338_363.jpg (total 66)
# Saved: thumbs_data\THUMBS_UP\20250816_195338_555.jpg (total 67)
# Saved: thumbs_data\THUMBS_UP\20250816_195338_763.jpg (total 68)
# Saved: thumbs_data\THUMBS_UP\20250816_195338_955.jpg (total 69)
# Saved: thumbs_data\THUMBS_UP\20250816_195339_196.jpg (total 70)
# Saved: thumbs_data\THUMBS_UP\20250816_195339_402.jpg (total 71)
# Saved: thumbs_data\THUMBS_UP\20250816_195339_595.jpg (total 72)
# Saved: thumbs_data\THUMBS_UP\20250816_195339_804.jpg (total 73)
# Saved: thumbs_data\THUMBS_UP\20250816_195340_027.jpg (total 74)
# Saved: thumbs_data\THUMBS_UP\20250816_195340_235.jpg (total 75)
# Saved: thumbs_data\THUMBS_UP\20250816_195340_459.jpg (total 76)
# Saved: thumbs_data\THUMBS_UP\20250816_195340_668.jpg (total 77)
# Saved: thumbs_data\THUMBS_UP\20250816_195340_875.jpg (total 78)
# Saved: thumbs_data\THUMBS_UP\20250816_195341_067.jpg (total 79)
# Saved: thumbs_data\THUMBS_UP\20250816_195341_307.jpg (total 80)
# Saved: thumbs_data\THUMBS_UP\20250816_195341_500.jpg (total 81)
# Saved: thumbs_data\THUMBS_UP\20250816_195341_707.jpg (total 82)
# Saved: thumbs_data\THUMBS_UP\20250816_195341_900.jpg (total 83)
# Saved: thumbs_data\THUMBS_UP\20250816_195342_140.jpg (total 84)
# Saved: thumbs_data\THUMBS_UP\20250816_195342_378.jpg (total 85)
# Saved: thumbs_data\THUMBS_UP\20250816_195342_571.jpg (total 86)
# Saved: thumbs_data\THUMBS_UP\20250816_195342_780.jpg (total 87)
# Saved: thumbs_data\THUMBS_UP\20250816_195343_003.jpg (total 88)
# Saved: thumbs_data\THUMBS_UP\20250816_195343_212.jpg (total 89)
# Saved: thumbs_data\THUMBS_UP\20250816_195343_435.jpg (total 90)
# Saved: thumbs_data\THUMBS_UP\20250816_195343_644.jpg (total 91)
# Saved: thumbs_data\THUMBS_UP\20250816_195343_852.jpg (total 92)
# Saved: thumbs_data\THUMBS_UP\20250816_195344_045.jpg (total 93)
# Saved: thumbs_data\THUMBS_UP\20250816_195344_252.jpg (total 94)
# Saved: thumbs_data\THUMBS_UP\20250816_195344_475.jpg (total 95)
# Saved: thumbs_data\THUMBS_UP\20250816_195344_716.jpg (total 96)
# Saved: thumbs_data\THUMBS_UP\20250816_195344_875.jpg (total 97)
# Saved: thumbs_data\THUMBS_UP\20250816_195345_115.jpg (total 98)
# Saved: thumbs_data\THUMBS_UP\20250816_195345_307.jpg (total 99)
# Saved: thumbs_data\THUMBS_UP\20250816_195345_516.jpg (total 100)
# Saved: thumbs_data\THUMBS_UP\20250816_195345_754.jpg (total 101)
# Saved: thumbs_data\THUMBS_UP\20250816_195345_979.jpg (total 102)
# Saved: thumbs_data\THUMBS_UP\20250816_195346_187.jpg (total 103)
# Saved: thumbs_data\THUMBS_UP\20250816_195346_412.jpg (total 104)
# Saved: thumbs_data\THUMBS_UP\20250816_195346_620.jpg (total 105)
# Saved: thumbs_data\THUMBS_UP\20250816_195346_860.jpg (total 106)
# Saved: thumbs_data\THUMBS_UP\20250816_195347_115.jpg (total 107)
# Saved: thumbs_data\THUMBS_UP\20250816_195347_292.jpg (total 108)
# Saved: thumbs_data\THUMBS_UP\20250816_195347_516.jpg (total 109)
# Saved: thumbs_data\THUMBS_UP\20250816_195347_723.jpg (total 110)
# Saved: thumbs_data\THUMBS_UP\20250816_195347_994.jpg (total 111)
# Saved: thumbs_data\THUMBS_UP\20250816_195348_187.jpg (total 112)
# Saved: thumbs_data\THUMBS_UP\20250816_195348_428.jpg (total 113)
# Saved: thumbs_data\THUMBS_UP\20250816_195348_620.jpg (total 114)
# Saved: thumbs_data\THUMBS_UP\20250816_195348_860.jpg (total 115)
# Saved: thumbs_data\THUMBS_UP\20250816_195349_132.jpg (total 116)
# Saved: thumbs_data\THUMBS_UP\20250816_195349_322.jpg (total 117)
# Saved: thumbs_data\THUMBS_UP\20250816_195349_564.jpg (total 118)
# Saved: thumbs_data\THUMBS_UP\20250816_195349_788.jpg (total 119)
# Saved: thumbs_data\THUMBS_UP\20250816_195350_028.jpg (total 120)
# Saved: thumbs_data\THUMBS_UP\20250816_195350_235.jpg (total 121)
# Saved: thumbs_data\THUMBS_UP\20250816_195350_459.jpg (total 122)
# Saved: thumbs_data\THUMBS_UP\20250816_195350_668.jpg (total 123)
# Saved: thumbs_data\THUMBS_UP\20250816_195350_892.jpg (total 124)
# Saved: thumbs_data\THUMBS_UP\20250816_195351_132.jpg (total 125)
# Saved: thumbs_data\THUMBS_UP\20250816_195351_339.jpg (total 126)
# Saved: thumbs_data\THUMBS_UP\20250816_195351_563.jpg (total 127)
# Saved: thumbs_data\THUMBS_UP\20250816_195351_803.jpg (total 128)
# Saved: thumbs_data\THUMBS_UP\20250816_195352_028.jpg (total 129)
# Saved: thumbs_data\THUMBS_UP\20250816_195352_267.jpg (total 130)
# Saved: thumbs_data\THUMBS_UP\20250816_195352_475.jpg (total 131)
# Saved: thumbs_data\THUMBS_UP\20250816_195352_700.jpg (total 132)
# Saved: thumbs_data\THUMBS_UP\20250816_195352_940.jpg (total 133)
# Saved: thumbs_data\THUMBS_UP\20250816_195353_132.jpg (total 134)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195405_885.jpg (total 135)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_348.jpg (total 136)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_413.jpg (total 137)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_475.jpg (total 138)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_539.jpg (total 139)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_603.jpg (total 140)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_683.jpg (total 141)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_747.jpg (total 142)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195406_843.jpg (total 143)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_180.jpg (total 144)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_675.jpg (total 145)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_739.jpg (total 146)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_820.jpg (total 147)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_852.jpg (total 148)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195407_946.jpg (total 149)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_012.jpg (total 150)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_075.jpg (total 151)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_156.jpg (total 152)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_198.jpg (total 153)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_252.jpg (total 154)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_347.jpg (total 155)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_412.jpg (total 156)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_474.jpg (total 157)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_555.jpg (total 158)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_587.jpg (total 159)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_651.jpg (total 160)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_746.jpg (total 161)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_812.jpg (total 162)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_892.jpg (total 163)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_932.jpg (total 164)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195408_987.jpg (total 165)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_050.jpg (total 166)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_146.jpg (total 167)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_212.jpg (total 168)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_292.jpg (total 169)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_334.jpg (total 170)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_387.jpg (total 171)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_451.jpg (total 172)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_548.jpg (total 173)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_612.jpg (total 174)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_692.jpg (total 175)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_724.jpg (total 176)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_756.jpg (total 177)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_820.jpg (total 178)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_884.jpg (total 179)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195409_979.jpg (total 180)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_060.jpg (total 181)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_092.jpg (total 182)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_156.jpg (total 183)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_220.jpg (total 184)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_282.jpg (total 185)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_396.jpg (total 186)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_438.jpg (total 187)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_492.jpg (total 188)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_554.jpg (total 189)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_620.jpg (total 190)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_682.jpg (total 191)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_795.jpg (total 192)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_827.jpg (total 193)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_891.jpg (total 194)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195410_956.jpg (total 195)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_020.jpg (total 196)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_083.jpg (total 197)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_172.jpg (total 198)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_227.jpg (total 199)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_292.jpg (total 200)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_355.jpg (total 201)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_420.jpg (total 202)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_483.jpg (total 203)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_572.jpg (total 204)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_628.jpg (total 205)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_692.jpg (total 206)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_756.jpg (total 207)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_820.jpg (total 208)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_899.jpg (total 209)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195411_964.jpg (total 210)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_027.jpg (total 211)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_092.jpg (total 212)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_155.jpg (total 213)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_220.jpg (total 214)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_300.jpg (total 215)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_362.jpg (total 216)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_396.jpg (total 217)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_429.jpg (total 218)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_489.jpg (total 219)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_555.jpg (total 220)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_636.jpg (total 221)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_700.jpg (total 222)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_763.jpg (total 223)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_827.jpg (total 224)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_892.jpg (total 225)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195412_955.jpg (total 226)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_036.jpg (total 227)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_100.jpg (total 228)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_164.jpg (total 229)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_228.jpg (total 230)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_292.jpg (total 231)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_356.jpg (total 232)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_435.jpg (total 233)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_500.jpg (total 234)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_564.jpg (total 235)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_627.jpg (total 236)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_692.jpg (total 237)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_772.jpg (total 238)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_835.jpg (total 239)
# Saved: thumbs_data\THUMBS_DOWN\20250816_195413_900.jpg (total 240)
# 촬영 종료

# %% [markdown]
# ## 3) 모델 학습 (ResNet18 전이학습)
# - `torchvision.models.resnet18(pretrained)` 사용
# - FC를 `num_classes=2`로 교체
# - `ImageFolder`로 `thumbs_data/THUMBS_UP`, `thumbs_data/THUMBS_DOWN`에서 학습/검증 분리

# %%
import torch, torch.nn as nn, torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import random_split, DataLoader

num_classes = 2
epochs = 5
batch_size = 16
lr = 1e-4

# 변환
train_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])
val_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

# 데이터셋
full_ds = datasets.ImageFolder(str(data_dir), transform=train_tf)
if len(full_ds.classes) != 2 or set(full_ds.classes) != set(CLASS_DIRS):
    print("경고: 폴더 클래스가 기대와 다릅니다:", full_ds.classes, "기대:", CLASS_DIRS)

val_ratio = 0.2
val_len = max(1, int(len(full_ds)*val_ratio))
train_len = len(full_ds) - val_len
train_ds, val_ds = random_split(full_ds, [train_len, val_len])
# 검증에는 augmentation 제거
val_ds.dataset.transform = val_tf

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# 모델
resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
resnet.fc = nn.Linear(resnet.fc.in_features, num_classes)
resnet = resnet.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet.parameters(), lr=lr)

def evaluate(model, loader):
    model.eval()
    correct = 0; total = 0; loss_sum = 0.0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            loss = criterion(out, y)
            loss_sum += loss.item()*x.size(0)
            pred = out.argmax(dim=1)
            correct += (pred==y).sum().item(); total += y.size(0)
    return loss_sum/total if total>0 else 0.0, (correct/total*100.0 if total>0 else 0.0)

best_acc = 0.0; last_train_loss = None
for ep in range(1, epochs+1):
    resnet.train()
    epoch_loss = 0.0; seen = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = resnet(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()*x.size(0)
        seen += x.size(0)
    last_train_loss = epoch_loss/seen if seen>0 else None
    val_loss, val_acc = evaluate(resnet, val_loader)
    print(f"[{ep}/{epochs}] train_loss={last_train_loss:.4f} | val_loss={val_loss:.4f} | val_acc={val_acc:.1f}%")
    if val_acc > best_acc:
        best_acc = val_acc
        stamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        best_path = model_dir / f"thumbs_resnet18_best_{stamp}.pth"
        torch.save({
            "state_dict": resnet.state_dict(),
            "classes": full_ds.classes,
            "val_acc": best_acc,
            "timestamp": stamp
        }, best_path)
        print("✅ Best model saved:", best_path)
# Out:
# C:\Users\jaeye\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [1/5] train_loss=0.1963 | val_loss=0.0059 | val_acc=100.0%
# ✅ Best model saved: models\thumbs_resnet18_best_20250816_195435.pth
# [2/5] train_loss=0.0071 | val_loss=0.0014 | val_acc=100.0%
# [3/5] train_loss=0.0022 | val_loss=0.0004 | val_acc=100.0%
# [4/5] train_loss=0.0010 | val_loss=0.0004 | val_acc=100.0%
# [5/5] train_loss=0.0014 | val_loss=0.0004 | val_acc=100.0%

# %% [markdown]
# ## 4) 실시간 분류 (학습된 모델 사용)
# - 저장된 best 모델 경로를 지정하거나, 폴더에서 가장 최근 파일을 자동 선택
# - 카메라 창은 **크게**
# - `q`로 종료

# %%
import glob, os, torch, cv2, numpy as np
from torchvision import models, transforms
import torch.nn as nn

# 가장 최근 best 모델 자동 선택
candidates = sorted(glob.glob(str(model_dir / "thumbs_resnet18_best_*.pth")))
assert len(candidates)>0, "저장된 모델이 없습니다. 먼저 학습 셀을 실행하세요."
model_path = candidates[-1]
print("로드 모델:", model_path)

ckpt = torch.load(model_path, map_location=device)
resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
resnet.fc = nn.Linear(resnet.fc.in_features, 2)
resnet.load_state_dict(ckpt["state_dict"], strict=False)
resnet = resnet.to(device).eval()
classes = ckpt.get("classes", CLASS_DIRS)
print("클래스:", classes)

infer_tf = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

cap, method = setup_camera_with_retry()
if cap is None:
    raise RuntimeError("Camera init failed.")

cv2.namedWindow(WINDOW_NAME, cv2.WINDOW_NORMAL)
cv2.resizeWindow(WINDOW_NAME, REQ_W, REQ_H)

fps, t0, cnt = 0.0, time.time(), 0
try:
    while True:
        ret, frame = cap.read()
        if not ret: 
            time.sleep(0.05); continue
        frame = cv2.flip(frame, 1)
        x = infer_tf(frame).unsqueeze(0).to(device)
        with torch.no_grad():
            out = resnet(x)
            prob = torch.softmax(out, dim=1)[0].detach().cpu().numpy()
        idx = int(np.argmax(prob)); conf = float(prob[idx])
        label = classes[idx] if idx<len(classes) else str(idx)

        cnt += 1
        if cnt % 20 == 0:
            now = time.time(); fps = 20.0/(now - t0); t0 = now

        cv2.putText(frame, f"{label} {conf:.2f} | {fps:.1f} FPS", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.1, (0,255,255), 2, cv2.LINE_AA)
        cv2.imshow(WINDOW_NAME, frame)
        k = cv2.waitKey(1) & 0xFF
        if k == ord('q') or k == 27:
            break
finally:
    cap.release(); cv2.destroyAllWindows()
    print("종료")
# Out:
# 로드 모델: models\thumbs_resnet18_best_20250816_195435.pth
# 클래스: ['THUMBS_DOWN', 'THUMBS_UP']
# Attempting V4L2_YUYV...
# Failed to open camera with V4L2_YUYV
# Attempting V4L2_MJPEG...
# Failed to open camera with V4L2_MJPEG
# Attempting DEFAULT...
# Camera initialized successfully with DEFAULT
# 종료
